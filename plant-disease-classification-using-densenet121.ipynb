# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
       # print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Firstly Trained on Kaggle GPU

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import DenseNet121

# %%
disease_types = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','Potato___Late_blight','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
data_dir = 'C:/Users/LENOVO/Downloads/archive (1)/PlantVillage/PlantVillage'
train_dir = os.path.join(data_dir)
#test_dir = os.path.join(data_dir, 'test')

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                                                 File  DiseaseID  \
# 0  Pepper__bell___Bacterial_spot/0022d6b7-d47c-4e...          0
# 1  Pepper__bell___Bacterial_spot/006adb74-934f-44...          0
# 2  Pepper__bell___Bacterial_spot/00f2e69a-1e56-41...          0
# 3  Pepper__bell___Bacterial_spot/01613cd0-d3cd-4e...          0
# 4  Pepper__bell___Bacterial_spot/0169b9ac-07b9-4b...          0
#
#                     Disease Type
# 0  Pepper__bell___Bacterial_spot
# 1  Pepper__bell___Bacterial_spot
# 2  Pepper__bell___Bacterial_spot
# 3  Pepper__bell___Bacterial_spot
# 4  Pepper__bell___Bacterial_spot

# %%
# Randomize the order of training set
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                                                 File  DiseaseID  \
# 0  Tomato_healthy/9d197d8a-3f35-401a-8aa4-39f7e69...         14
# 1  Potato___Early_blight/900514b4-8768-4370-bc53-...          2
# 2  Tomato_Septoria_leaf_spot/dc5f2f7d-8b86-402e-8...          9
# 3  Tomato_healthy/e3b5600f-9c88-4060-826f-aa7c972...         14
# 4  Tomato_Leaf_Mold/2e84cbfc-af2c-4c2b-9273-84275...          8
#
#                 Disease Type
# 0             Tomato_healthy
# 1      Potato___Early_blight
# 2  Tomato_Septoria_leaf_spot
# 3             Tomato_healthy
# 4           Tomato_Leaf_Mold

# %%
# Plot a histogram
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
# Display images for different species
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('Tomato_Bacterial_spot', 5, 5)

# %%
IMAGE_SIZE = 64

def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) 
# Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 20639it [05:10, 66.53it/s]
# Train Shape: (20639, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=15)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 50
SIZE=64
N_ch=3

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(15,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet121 (Functional)     (None, None, None, 1024)  7037504
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 15)                3855
# =================================================================
# Total params: 7,308,963
# Trainable params: 7,222,755
# Non-trainable params: 86,208
# _________________________________________________________________
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 257/257 - 855s - loss: 2.5097 - accuracy: 0.3309 - val_loss: 1.7873 - val_accuracy: 0.4782
#
# Epoch 00001: val_loss improved from inf to 1.78728, saving model to model.h5
# Epoch 2/50
# 257/257 - 831s - loss: 0.9953 - accuracy: 0.6855 - val_loss: 0.6703 - val_accuracy: 0.7861
#
# Epoch 00002: val_loss improved from 1.78728 to 0.67032, saving model to model.h5
# Epoch 3/50
# 257/257 - 756s - loss: 0.5955 - accuracy: 0.8083 - val_loss: 0.8564 - val_accuracy: 0.7379
#
# Epoch 00003: val_loss did not improve from 0.67032
# Epoch 4/50
# 257/257 - 52133s - loss: 0.4136 - accuracy: 0.8665 - val_loss: 0.3124 - val_accuracy: 0.9038
#
# Epoch 00004: val_loss improved from 0.67032 to 0.31238, saving model to model.h5
# Epoch 5/50
# 257/257 - 552s - loss: 0.3245 - accuracy: 0.8952 - val_loss: 1.6068 - val_accuracy: 0.6344
#
# Epoch 00005: val_loss did not improve from 0.31238
# Epoch 6/50
# 257/257 - 561s - loss: 0.2732 - accuracy: 0.9143 - val_loss: 0.5314 - val_accuracy: 0.8416
#
# Epoch 00006: val_loss did not improve from 0.31238
# Epoch 7/50
# 257/257 - 574s - loss: 0.2477 - accuracy: 0.9248 - val_loss: 0.2489 - val_accuracy: 0.9218
#
# Epoch 00007: val_loss improved from 0.31238 to 0.24890, saving model to model.h5
# Epoch 8/50
# 257/257 - 583s - loss: 0.2023 - accuracy: 0.9360 - val_loss: 0.2927 - val_accuracy: 0.9145
#
# Epoch 00008: val_loss did not improve from 0.24890
# Epoch 9/50
# 257/257 - 603s - loss: 0.1817 - accuracy: 0.9399 - val_loss: 0.1998 - val_accuracy: 0.9339
#
# Epoch 00009: val_loss improved from 0.24890 to 0.19983, saving model to model.h5
# Epoch 10/50
# 257/257 - 641s - loss: 0.1697 - accuracy: 0.9465 - val_loss: 1.2860 - val_accuracy: 0.6989
#
# Epoch 00010: val_loss did not improve from 0.19983
# Epoch 11/50
# 257/257 - 6979s - loss: 0.1518 - accuracy: 0.9523 - val_loss: 0.4586 - val_accuracy: 0.8798
#
# Epoch 00011: val_loss did not improve from 0.19983
# Epoch 12/50
# 257/257 - 770s - loss: 0.1342 - accuracy: 0.9565 - val_loss: 0.2338 - val_accuracy: 0.9285
#
# Epoch 00012: val_loss did not improve from 0.19983
# Epoch 13/50
# 257/257 - 779s - loss: 0.1311 - accuracy: 0.9571 - val_loss: 0.2892 - val_accuracy: 0.9152
#
# Epoch 00013: val_loss did not improve from 0.19983
# Epoch 14/50
# 257/257 - 757s - loss: 0.1225 - accuracy: 0.9616 - val_loss: 0.1417 - val_accuracy: 0.9523
#
# Epoch 00014: val_loss improved from 0.19983 to 0.14170, saving model to model.h5
# Epoch 15/50
# 257/257 - 766s - loss: 0.1155 - accuracy: 0.9625 - val_loss: 1.8873 - val_accuracy: 0.5950
#
# Epoch 00015: val_loss did not improve from 0.14170
# Epoch 16/50
# 257/257 - 741s - loss: 0.1190 - accuracy: 0.9616 - val_loss: 0.3959 - val_accuracy: 0.8859
#
# Epoch 00016: val_loss did not improve from 0.14170
# Epoch 17/50
# 257/257 - 795s - loss: 0.1049 - accuracy: 0.9667 - val_loss: 0.3607 - val_accuracy: 0.8922
#
# Epoch 00017: val_loss did not improve from 0.14170
# Epoch 18/50
# 257/257 - 781s - loss: 0.0995 - accuracy: 0.9677 - val_loss: 1.3976 - val_accuracy: 0.6906
#
# Epoch 00018: val_loss did not improve from 0.14170
# Epoch 19/50
# 257/257 - 761s - loss: 0.0923 - accuracy: 0.9698 - val_loss: 0.3758 - val_accuracy: 0.8944
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00019: val_loss did not improve from 0.14170
# Epoch 20/50
# 257/257 - 786s - loss: 0.0746 - accuracy: 0.9757 - val_loss: 0.4013 - val_accuracy: 0.8920
#
# Epoch 00020: val_loss did not improve from 0.14170
# Epoch 21/50
# 257/257 - 753s - loss: 0.0636 - accuracy: 0.9791 - val_loss: 0.0893 - val_accuracy: 0.9702
#
# Epoch 00021: val_loss improved from 0.14170 to 0.08927, saving model to model.h5
# Epoch 22/50
# 257/257 - 770s - loss: 0.0622 - accuracy: 0.9808 - val_loss: 0.2876 - val_accuracy: 0.9215
#
# Epoch 00022: val_loss did not improve from 0.08927
# Epoch 23/50
# 257/257 - 790s - loss: 0.0613 - accuracy: 0.9813 - val_loss: 0.2757 - val_accuracy: 0.9220
#
# Epoch 00023: val_loss did not improve from 0.08927
# Epoch 24/50
# 257/257 - 747s - loss: 0.0541 - accuracy: 0.9827 - val_loss: 0.1245 - val_accuracy: 0.9588
#
# Epoch 00024: val_loss did not improve from 0.08927
# Epoch 25/50
# 257/257 - 741s - loss: 0.0564 - accuracy: 0.9824 - val_loss: 0.6638 - val_accuracy: 0.8353
#
# Epoch 00025: val_loss did not improve from 0.08927
# Epoch 26/50
# 257/257 - 812s - loss: 0.0533 - accuracy: 0.9824 - val_loss: 0.7930 - val_accuracy: 0.8215
#
# Epoch 00026: val_loss did not improve from 0.08927
# Epoch 27/50
# 257/257 - 768s - loss: 0.0500 - accuracy: 0.9835 - val_loss: 0.2137 - val_accuracy: 0.9404
#
# Epoch 00027: val_loss did not improve from 0.08927
# Epoch 28/50
# 257/257 - 738s - loss: 0.0474 - accuracy: 0.9842 - val_loss: 0.4415 - val_accuracy: 0.9007
#
# Epoch 00028: val_loss did not improve from 0.08927
# Epoch 29/50
# 257/257 - 726s - loss: 0.0474 - accuracy: 0.9851 - val_loss: 0.2769 - val_accuracy: 0.9305
#
# Epoch 00029: val_loss did not improve from 0.08927
# Epoch 30/50
# 257/257 - 709s - loss: 0.0535 - accuracy: 0.9834 - val_loss: 0.3320 - val_accuracy: 0.9147
#
# Epoch 00030: val_loss did not improve from 0.08927
# Epoch 31/50
# 257/257 - 788s - loss: 0.0481 - accuracy: 0.9849 - val_loss: 0.2600 - val_accuracy: 0.9300
#
# Epoch 00031: val_loss did not improve from 0.08927
# Epoch 32/50
# 257/257 - 811s - loss: 0.0445 - accuracy: 0.9860 - val_loss: 0.1798 - val_accuracy: 0.9460
#
# Epoch 00032: val_loss did not improve from 0.08927
# Epoch 33/50
# 257/257 - 772s - loss: 0.0433 - accuracy: 0.9860 - val_loss: 0.3556 - val_accuracy: 0.9106
#
# Epoch 00033: val_loss did not improve from 0.08927
# Epoch 34/50
# 257/257 - 821s - loss: 0.0464 - accuracy: 0.9865 - val_loss: 0.1816 - val_accuracy: 0.9491
#
# Epoch 00034: val_loss did not improve from 0.08927
# Epoch 35/50
# 257/257 - 785s - loss: 0.0420 - accuracy: 0.9857 - val_loss: 0.5125 - val_accuracy: 0.8808
#
# Epoch 00035: val_loss did not improve from 0.08927
# Epoch 36/50
# 257/257 - 808s - loss: 0.0388 - accuracy: 0.9881 - val_loss: 0.0975 - val_accuracy: 0.9707
#
# Epoch 00036: val_loss did not improve from 0.08927
# Epoch 37/50
# 257/257 - 827s - loss: 0.0410 - accuracy: 0.9871 - val_loss: 0.1362 - val_accuracy: 0.9583
#
# Epoch 00037: val_loss did not improve from 0.08927
# Epoch 38/50
# 257/257 - 790s - loss: 0.0428 - accuracy: 0.9852 - val_loss: 0.1765 - val_accuracy: 0.9474
#
# Epoch 00038: val_loss did not improve from 0.08927
# Epoch 39/50
# 257/257 - 751s - loss: 0.0397 - accuracy: 0.9870 - val_loss: 0.6658 - val_accuracy: 0.8452
#
# Epoch 00039: val_loss did not improve from 0.08927
# Epoch 40/50
# 257/257 - 762s - loss: 0.0390 - accuracy: 0.9870 - val_loss: 0.1506 - val_accuracy: 0.9566
#
# Epoch 00040: val_loss did not improve from 0.08927
# Epoch 41/50
# 257/257 - 792s - loss: 0.0350 - accuracy: 0.9884 - val_loss: 0.3068 - val_accuracy: 0.9256
#
# Epoch 00041: val_loss did not improve from 0.08927
# Epoch 42/50
# 257/257 - 797s - loss: 0.0415 - accuracy: 0.9869 - val_loss: 0.1345 - val_accuracy: 0.9639
#
# Epoch 00042: val_loss did not improve from 0.08927
# Epoch 43/50
# 257/257 - 732s - loss: 0.0359 - accuracy: 0.9883 - val_loss: 0.2042 - val_accuracy: 0.9460
#
# Epoch 00043: val_loss did not improve from 0.08927
# Epoch 44/50
# 257/257 - 732s - loss: 0.0363 - accuracy: 0.9890 - val_loss: 0.5137 - val_accuracy: 0.8791
#
# Epoch 00044: val_loss did not improve from 0.08927
# Epoch 45/50
# 257/257 - 724s - loss: 0.0334 - accuracy: 0.9893 - val_loss: 0.2977 - val_accuracy: 0.9266
#
# Epoch 00045: val_loss did not improve from 0.08927
# Epoch 46/50
# 257/257 - 723s - loss: 0.0319 - accuracy: 0.9893 - val_loss: 0.2177 - val_accuracy: 0.9455
#
# Epoch 00046: val_loss did not improve from 0.08927
# Epoch 47/50
# 257/257 - 705s - loss: 0.0359 - accuracy: 0.9894 - val_loss: 0.4394 - val_accuracy: 0.9036
#
# Epoch 00047: val_loss did not improve from 0.08927
# Epoch 48/50
# 257/257 - 714s - loss: 0.0346 - accuracy: 0.9895 - val_loss: 0.3581 - val_accuracy: 0.9147
#
# Epoch 00048: val_loss did not improve from 0.08927
# Epoch 49/50
# 257/257 - 741s - loss: 0.0284 - accuracy: 0.9908 - val_loss: 0.8683 - val_accuracy: 0.8055
#
# Epoch 00049: val_loss did not improve from 0.08927
# Epoch 50/50
# 257/257 - 739s - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.1453 - val_accuracy: 0.9571
#
# Epoch 00050: val_loss did not improve from 0.08927

# %%
#model = load_model('../output/kaggle/working/model.h5')c f
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 129/129 [==============================] - 42s 325ms/step - loss: 0.1453 - accuracy: 0.9571
# Final Loss: 0.14533445239067078, Final Accuracy: 0.9571220874786377

# %%
model.save('pcmodelnew.h5')
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 144.41374999999996, 'Predicted')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Testing Disease Prediction

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('C:/Users/LENOVO/Downloads/archive (1)/PlantVillage/PlantVillage/Potato___Early_blight/042135e2-e126-4900-9212-d42d900b8125___RS_Early.B 8791.JPG', grayscale=False, target_size=(64, 64))
show_img=image.load_img('C:/Users/LENOVO/Downloads/archive (1)/PlantVillage/PlantVillage/Potato___Early_blight/042135e2-e126-4900-9212-d42d900b8125___RS_Early.B 8791.JPG', grayscale=False, target_size=(200, 200))
disease_class = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','Potato___Late_blight','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
#x = np.array(x, 'float32')
x /= 255

custom = model.predict(x)
print(custom[0])



#x = x.reshape([64, 64]);

#plt.gray()
plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [2.8037985e-09 1.5686960e-09 9.9999869e-01 2.0380784e-09 8.5955855e-07
#  4.7835766e-14 2.5538972e-08 5.2848605e-09 9.5015118e-10 7.7987539e-10
#  1.0438642e-11 1.1532604e-13 1.1298291e-09 2.4450949e-07 1.9209493e-07]
# Prediction: Potato___Early_blight
